# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroMartinez128/ACT-21-CLASE-CELULAR-Fecha-abril-2026/blob/main/Act_21_clase_celular_Pedro_Martinez_0093.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Pedro Martinez NL = 34 Fecha 22/Abril/2026
# #### NC = 2530805128**0093**
# ## Clase celular
# ---
#
# <img src="https://raw.githubusercontent.com/PedroMartinez128/ACT-21-CLASE-CELULAR-Fecha-abril-2026/refs/heads/main/infografia%2030.png" width="400" align="left">

# %%
class Celular:
    def __init__(self, marca, modelo, precio):
        self.marca = marca
        self.modelo = modelo
        self.precio = precio
        self.encendido = False

    def encender(self):
        self.encendido = True
        print(f"El {self.modelo} se ha encendido.")

    def mostrar_info(self):
        print(f"Celular: {self.marca} {self.modelo}, Precio: ${self.precio}")

# Instanciación
celular1 = Celular("Samsung", "Galaxy S23", 800)
celular2 = Celular("Apple", "iPhone 15", 1000)
# Llamadas a las funciones para cada objeto
print(50*("="))
print("Celular 1 🤳:")
celular1.mostrar_info()
celular1.encender()
print(50*("="))
print("\nCelular2 🤳:")
celular2.mostrar_info()
celular2.encender()
print(50*("="))
print("----Programa terminado----")
print("software creado por Pedro Martinez NL = 34")
# Out:
# ...
# Celular 1 🤳:
# Celular: Samsung Galaxy S23, Precio: $800
# El Galaxy S23 se ha encendido.
# ...
#
# Celular2 🤳:
# Celular: Apple iPhone 15, Precio: $1000
# El iPhone 15 se ha encendido.
# ...
# ----Programa terminado----
# software creado por Pedro Martinez NL = 34

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/PedroMartinez128/ACT-21-CLASE-CELULAR-Fecha-abril-2026/refs/heads/main/LogicadeFuncionamiento.png)
